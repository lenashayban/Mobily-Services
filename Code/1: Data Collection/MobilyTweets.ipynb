# %%
#Import the necessary methods from tweepy library
import tweepy as tw
import json
import pandas as pd

# %%
#Variables that contains the user credentials to access Twitter API 

#ACCESS

access_token = "1270963428966965248-XRJRh756cgXNeGECXAY0jmUdXFPSCk"
access_token_secret = "7tv1VQaXVHRBxb5MWa8x8Pw0b5br0UcDzQ7MgS67GOTJx"

#CONSUME

consumer_key = "7LtqFLE6s3rFDip9liqKdYo6s"
consumer_secret = "DwF3iQJIpaYX3RHjVj3c62LiWnWtAMgetkedCYfATRCdLKcxZG"

# %%
#This handles Twitter authetification and the connection to Twitter Streaming API

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)


api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Define the search term and the date_since date as variables
search_words = "Mobily"
date_since = "2022-3-6"

# %%
results = []

#Get the first items based on the search query
for tweet in tw.Cursor(api.search_tweets,tweet_mode='extended',q=search_words,since=date_since).items(9000):
    results.append(tweet)
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# ...

# %%
# Verify the number of items returned
print(len(results))
# Out:
# 1510

# %%
def toDataFrame(tweets):

    DataSet = pd.DataFrame()

    DataSet['tweetID'] = pd.Series([tweet.id for tweet in tweets])
    DataSet['tweetText'] = pd.Series([tweet.full_text for tweet in tweets])
    DataSet['tweetRetweetCt'] = pd.Series([tweet.retweet_count for tweet 
    in tweets])
    DataSet['tweetFavoriteCt'] = pd.Series([tweet.favorite_count for tweet 
    in tweets])
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]

    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet  in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
  
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
   
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet  in tweets]


    return DataSet

# %%
DataSet = toDataFrame(results)

# %%
#Display last tweets
display(DataSet)
# Out:
#                   tweetID                                          tweetText  \
# 0     1501652769387782162  @Mobily معقولة النت كان كويس وأربعة أبراج الحي...
# 1     1501652670414741505  RT @tariqaljaser: ✅ معلومة مفيدة للأشخاص اللي ...
# 2     1501651176487538697  @Mobily السلام عليكم، أبغى أستفسر عن باقات الم...
# 3     1501650836581191681                   @Turki_alalshikh صح عليك يا رشاش
# 4     1501649642320240648  @0_0_70 مرحبا ، أسرع طريقة للحصول على شريحة صو...
# ...                   ...                                                ...
# 1505  1500269594786807810  @Mobily السلام عليكم حابه استفسر هل يوجد عندكم...
# 1506  1500269114346151943  @b1b_5 في حالة استيفاء جميع شروط الاقسام نعم ي...
# 1507  1500266017083334660  @b1b_5 وللمزيد من التفاصيل عن الاجهزة المتاحة ...
# 1508  1500265913219751937  @b1b_5 ولتحميل التطبيق زيارة https://t.co/SJdI...
# 1509  1500261375444201475   @Mobily السلام عليكم\nابي استرجع رقمي مفصول مؤقت
#
# ...

# %%
DataSet.to_csv('MobilyTweets.csv',index=False,encoding='utf-8-sig')
